# %%
import numpy as np
import matplotlib.pyplot as plt
import os, cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm      # a nice pretty percentage bar for tasks.
from random import shuffle

# %%
TRAIN_DIR = '../input/train/'
TRAIN_DIR_DOG = '../input/train/dog/' 
TRAIN_DIR_CAT = '../input/train/cat/'

VAL_DIR = '../input/validation/'
VAL_DIR_DOG = '../input/validation/dog/'
VAL_DIR_CAT = '../input/validation/cat/'

ROWS = 64
COLS = 64
CHANNELS = 3
TOTAL_COUNT = 12500
TRAIN_COUNT = int(TOTAL_COUNT*0.75)
VAL_COUNT = int(TOTAL_COUNT*0.25)

data_dict = {}

dog_train_list = [TRAIN_DIR_DOG+name for i,name in \
                  enumerate(os.listdir(TRAIN_DIR_DOG)) if i < TRAIN_COUNT]
cat_train_list = [TRAIN_DIR_CAT+name for i,name in \
                  enumerate(os.listdir(TRAIN_DIR_CAT)) if i < TRAIN_COUNT]

data_dict['train_data'] = dog_train_list + cat_train_list
data_dict['train_labels'] = [1]*TRAIN_COUNT + [0]*TRAIN_COUNT

dog_val_list = [VAL_DIR_DOG+name for i, name in \
                enumerate(os.listdir(VAL_DIR_DOG)) if i < VAL_COUNT]
cat_val_list = [VAL_DIR_CAT+name for i, name in \
                enumerate(os.listdir(VAL_DIR_CAT)) if i < VAL_COUNT]

data_dict['val_data'] = dog_val_list + cat_val_list
data_dict['val_labels']= [1]*VAL_COUNT + [0]*VAL_COUNT
          
print(len(data_dict['train_data']))
print(len(data_dict['val_data']))
# Out:
# 18750
# 6250

# %%
def load_image(file_path, size=(ROWS,COLS)):
    img = cv2.imread(file_path, cv2.IMREAD_COLOR)
    b,g,r = cv2.split(img)
    rgb_img = cv2.merge([r,g,b])
    return cv2.resize(rgb_img, (ROWS,COLS))
    

def load_image_list(file_list):
    count = len(file_list)
    data = np.ndarray((count, ROWS, COLS, CHANNELS),\
                      dtype=np.uint8)
    for i, image_name in tqdm(enumerate(file_list)):
        data[i] = load_image(image_name)
    return data / 255.0
    
data_dict['train_data'] = load_image_list(\
                            data_dict['train_data'])
data_dict['val_data'] = load_image_list(\
                            data_dict['val_data'])
# Out:
# 18750it [00:47, 393.53it/s]
# 6250it [00:15, 399.82it/s]

# %%
f, axarr = plt.subplots(2,2)
axarr[0,0].set_title(data_dict['train_labels'][0])
axarr[0,0].imshow(data_dict['train_data'][0])

axarr[1,0].set_title(data_dict['train_labels'][TRAIN_COUNT-1])
axarr[1,0].imshow(data_dict['train_data'][TRAIN_COUNT-1])

axarr[0,1].set_title(data_dict['train_labels'][TRAIN_COUNT])
axarr[0,1].imshow(data_dict['train_data'][TRAIN_COUNT])

axarr[1,1].set_title(data_dict['train_labels'][TRAIN_COUNT*2 -1])
axarr[1,1].imshow(data_dict['train_data'][TRAIN_COUNT*2 -1])
plt.show()

# %%
model = Sequential()
model.add(Conv2D(filters=4, kernel_size=(4,4),\
                 padding='Same', activation='relu',\
                 input_shape=(ROWS,COLS,CHANNELS)))
model.add(Conv2D(filters=8, kernel_size=(4,4),\
                 padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Conv2D(filters=16, kernel_size=(8,8),\
                 padding='Same', activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(8,8),\
                 padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(4,4)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(8**2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

optimizer = SGD(lr=0.03)
model.compile(optimizer=optimizer,
              loss="binary_crossentropy",
              metrics=["accuracy"])

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 64, 64, 4)         196
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 8)         520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 16)        8208
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        32800
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                131136
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 172,925
# Trainable params: 172,925
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

filepath='cat_dog_v4a1'

early_stop = EarlyStopping(monitor='val_loss',
                           patience=5)

checkpoint = ModelCheckpoint(filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=False,
                             mode='min')

epochs = 160
history = model.fit(x=data_dict['train_data'],
                    y=data_dict['train_labels'],
                    batch_size=32,
                    epochs=epochs,
                    verbose=2,
                    shuffle=True,
                    validation_data=(data_dict['val_data'],
                                     data_dict['val_labels']),
                    callbacks=[early_stop, checkpoint])
# Out:
# Train on 18750 samples, validate on 6250 samples
# Epoch 1/160
#  - 11s - loss: 0.6918 - acc: 0.5323 - val_loss: 0.6869 - val_acc: 0.5694
#
# Epoch 00001: saving model to cat_dog_v4a1
# Epoch 2/160
#  - 10s - loss: 0.6788 - acc: 0.5761 - val_loss: 0.6804 - val_acc: 0.5613
#
# Epoch 00002: saving model to cat_dog_v4a1
# Epoch 3/160
#  - 10s - loss: 0.6676 - acc: 0.5968 - val_loss: 0.6674 - val_acc: 0.6093
#
# Epoch 00003: saving model to cat_dog_v4a1
# Epoch 4/160
#  - 10s - loss: 0.6471 - acc: 0.6297 - val_loss: 0.6302 - val_acc: 0.6586
#
# Epoch 00004: saving model to cat_dog_v4a1
# Epoch 5/160
#  - 10s - loss: 0.6276 - acc: 0.6571 - val_loss: 0.6154 - val_acc: 0.6805
#
# Epoch 00005: saving model to cat_dog_v4a1
# Epoch 6/160
#  - 10s - loss: 0.6088 - acc: 0.6720 - val_loss: 0.5983 - val_acc: 0.6886
#
# Epoch 00006: saving model to cat_dog_v4a1
# Epoch 7/160
#  - 10s - loss: 0.5919 - acc: 0.6831 - val_loss: 0.5801 - val_acc: 0.7069
#
# Epoch 00007: saving model to cat_dog_v4a1
# Epoch 8/160
#  - 10s - loss: 0.5800 - acc: 0.6972 - val_loss: 0.5983 - val_acc: 0.6755
#
# Epoch 00008: saving model to cat_dog_v4a1
# Epoch 9/160
#  - 10s - loss: 0.5642 - acc: 0.7077 - val_loss: 0.5922 - val_acc: 0.6901
#
# Epoch 00009: saving model to cat_dog_v4a1
# Epoch 10/160
#  - 10s - loss: 0.5519 - acc: 0.7158 - val_loss: 0.5337 - val_acc: 0.7339
#
# Epoch 00010: saving model to cat_dog_v4a1
# Epoch 11/160
#  - 11s - loss: 0.5359 - acc: 0.7311 - val_loss: 0.5147 - val_acc: 0.7442
#
# Epoch 00011: saving model to cat_dog_v4a1
# Epoch 12/160
#  - 10s - loss: 0.5254 - acc: 0.7343 - val_loss: 0.4892 - val_acc: 0.7669
#
# Epoch 00012: saving model to cat_dog_v4a1
# Epoch 13/160
#  - 10s - loss: 0.5034 - acc: 0.7523 - val_loss: 0.4722 - val_acc: 0.7773
#
# Epoch 00013: saving model to cat_dog_v4a1
# Epoch 14/160
#  - 10s - loss: 0.4986 - acc: 0.7537 - val_loss: 0.4852 - val_acc: 0.7702
#
# Epoch 00014: saving model to cat_dog_v4a1
# Epoch 15/160
#  - 10s - loss: 0.4845 - acc: 0.7639 - val_loss: 0.4882 - val_acc: 0.7651
#
# Epoch 00015: saving model to cat_dog_v4a1
# Epoch 16/160
#  - 10s - loss: 0.4762 - acc: 0.7706 - val_loss: 0.4453 - val_acc: 0.7958
#
# Epoch 00016: saving model to cat_dog_v4a1
# Epoch 17/160
#  - 10s - loss: 0.4670 - acc: 0.7757 - val_loss: 0.4441 - val_acc: 0.7960
#
# Epoch 00017: saving model to cat_dog_v4a1
# Epoch 18/160
#  - 10s - loss: 0.4576 - acc: 0.7841 - val_loss: 0.4356 - val_acc: 0.8005
#
# Epoch 00018: saving model to cat_dog_v4a1
# Epoch 19/160
#  - 10s - loss: 0.4494 - acc: 0.7864 - val_loss: 0.4399 - val_acc: 0.7928
#
# Epoch 00019: saving model to cat_dog_v4a1
# Epoch 20/160
#  - 10s - loss: 0.4423 - acc: 0.7901 - val_loss: 0.4538 - val_acc: 0.7882
#
# Epoch 00020: saving model to cat_dog_v4a1
# Epoch 21/160
#  - 10s - loss: 0.4389 - acc: 0.7954 - val_loss: 0.4357 - val_acc: 0.7963
#
# Epoch 00021: saving model to cat_dog_v4a1
# Epoch 22/160
#  - 10s - loss: 0.4243 - acc: 0.8009 - val_loss: 0.4071 - val_acc: 0.8202
#
# Epoch 00022: saving model to cat_dog_v4a1
# Epoch 23/160
#  - 10s - loss: 0.4203 - acc: 0.8058 - val_loss: 0.4210 - val_acc: 0.8070
#
# Epoch 00023: saving model to cat_dog_v4a1
# Epoch 24/160
#  - 10s - loss: 0.4119 - acc: 0.8083 - val_loss: 0.3983 - val_acc: 0.8178
#
# Epoch 00024: saving model to cat_dog_v4a1
# Epoch 25/160
#  - 10s - loss: 0.4011 - acc: 0.8141 - val_loss: 0.3938 - val_acc: 0.8221
#
# Epoch 00025: saving model to cat_dog_v4a1
# Epoch 26/160
#  - 10s - loss: 0.4050 - acc: 0.8121 - val_loss: 0.3959 - val_acc: 0.8158
#
# Epoch 00026: saving model to cat_dog_v4a1
# Epoch 27/160
#  - 10s - loss: 0.3977 - acc: 0.8183 - val_loss: 0.3871 - val_acc: 0.8227
#
# Epoch 00027: saving model to cat_dog_v4a1
# Epoch 28/160
#  - 10s - loss: 0.3911 - acc: 0.8255 - val_loss: 0.3760 - val_acc: 0.8309
#
# Epoch 00028: saving model to cat_dog_v4a1
# Epoch 29/160
#  - 10s - loss: 0.3863 - acc: 0.8235 - val_loss: 0.3718 - val_acc: 0.8323
#
# Epoch 00029: saving model to cat_dog_v4a1
# Epoch 30/160
#  - 10s - loss: 0.3807 - acc: 0.8252 - val_loss: 0.3634 - val_acc: 0.8371
#
# Epoch 00030: saving model to cat_dog_v4a1
# Epoch 31/160
#  - 10s - loss: 0.3776 - acc: 0.8294 - val_loss: 0.3527 - val_acc: 0.8430
#
# Epoch 00031: saving model to cat_dog_v4a1
# Epoch 32/160
#  - 10s - loss: 0.3692 - acc: 0.8305 - val_loss: 0.3621 - val_acc: 0.8392
#
# Epoch 00032: saving model to cat_dog_v4a1
# Epoch 33/160
#  - 10s - loss: 0.3657 - acc: 0.8331 - val_loss: 0.3557 - val_acc: 0.8443
#
# Epoch 00033: saving model to cat_dog_v4a1
# Epoch 34/160
#  - 10s - loss: 0.3598 - acc: 0.8384 - val_loss: 0.3647 - val_acc: 0.8390
#
# Epoch 00034: saving model to cat_dog_v4a1
# Epoch 35/160
#  - 10s - loss: 0.3588 - acc: 0.8384 - val_loss: 0.3566 - val_acc: 0.8376
#
# Epoch 00035: saving model to cat_dog_v4a1
# Epoch 36/160
#  - 10s - loss: 0.3526 - acc: 0.8405 - val_loss: 0.3585 - val_acc: 0.8414
#
# Epoch 00036: saving model to cat_dog_v4a1

# %%
fig, ax = plt.subplots(2,1)
# Loss Plot
ax[0].plot(history.history['loss'], color='b', label="Training Loss")
ax[0].plot(history.history['val_loss'], color='r', label='Validation Loss')

legend = ax[0].legend(loc='best', shadow=True)

# Accuracy Plot
ax[1].plot(history.history['acc'], color='b', label='Training Accuracy')
ax[1].plot(history.history['val_acc'], color='r', label='Validation Accuracy')
legend = ax[1].legend(loc='best', shadow=True)

# %%
data_dict['train_data'][0].shape
